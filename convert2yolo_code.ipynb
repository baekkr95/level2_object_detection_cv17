# %%
fold = 5

name_path = './yolov5/name.txt' # class info
# train_json_path = f'./stratified_kfold/cv_train_{fold}.json'
train_json_path = f'./stratified_kfold/cv_train_{fold}.json'

# val_json_path = f'./stratified_kfold/cv_val_{fold}.json'
train_text_path = f'./yolov5/train_path_{fold}.txt' # save as txt file
val_text_path = './yolov5/val_path.txt' # save as txt file

# !python ./convert2Yolo/example.py --datasets COCO \
                                  --img_path ./dataset \
                                  --label {train_json_path} \
                                  --convert_output_path ./dataset \
                                  --img_type '.jpg' \
                                  --manifest_path {train_text_path} \
                                  --cls_list_file {name_path}

# !python ./convert2Yolo/example.py --datasets COCO \
#                                   --img_path ./dataset \
#                                   --label {val_json_path} \
#                                   --convert_output_path ./dataset \
#                                   --img_type '.jpg' \
#                                   --manifest_path {val_text_path} \
#                                   --cls_list_file {name_path}
# Out:
# COCO Parsing:  |████████████████████████████████████████| 100.0% (18452/18452)  Complete
#
#
# YOLO Generating:|████████████████████████████████████████| 100.0% (3961/3961)  Complete
#
#
# YOLO Saving:   |████████████████████████████████████████| 100.0% (3961/3961)  Complete
